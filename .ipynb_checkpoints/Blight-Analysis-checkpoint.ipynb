# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
mjr_violations_orig = pd.read_csv('data/mjrhouse_violations.csv')

# %%
violations = mjr_violations_orig
violations.shape
# Out:
# (27863, 34)

# %%
# violations.head()

# %%
violations.drop(['Resolve','Compliance_Requested','Case_Type','CEB_Compliance_Requested','Tag_', 'VIN_',
       'Make', 'Color','Vehicle_Description', 'Address', 'Quantity','PARCEL_1', 'MAPSHEET','COUNTY', 'DESCRIPT'], axis=1, inplace = True)
violations.columns
# Out:
# Index(['Number', 'Violation', 'Inspector', 'Status', 'Primary_Party',
#        'Violation_Date', 'Compliance', 'Received_By', 'PARCEL_CLEAN',
#        'LATITUDE', 'LONGITUDE', 'Prop_Use_Code', 'Prop_Use_Desc', 'TRS_WATSON',
#        'SECTION_1', 'TOWNSHIP_1', 'RANGE_1', 'TD', 'RD'],
#       dtype='object')

# %%
#change to datetime format
violations["Violation_Date"] = pd.to_datetime(violations["Violation_Date"])
violations["Violation_Date"] = pd.to_datetime(violations['Compliance'])

# %% [markdown]
# # Blight Violations

# %%
blight_violations = violations[violations['Violation'].isin(['Blight-inducing Materials','Abandoned Vehicles And/or Blight Inducing Materials'])].reset_index(drop=True)
blight_violations.head()
# Out:
#         Number                                          Violation  \
# 0  CE-10-03462                          Blight-inducing Materials
# 1  CE-18-01217  Abandoned Vehicles And/or Blight Inducing Mate...
# 2  CE-10-03463                          Blight-inducing Materials
# 3  CE-10-01790                          Blight-inducing Materials
# 4  CE-10-00340                          Blight-inducing Materials
#
#               Inspector  Status  \
# 0  Walter L. Booth, Sr.  Opened
# 1           Todd Martin  Opened
# 2  Walter L. Booth, Sr.  Opened
# 3  Walter L. Booth, Sr.  Opened
# 4  Walter L. Booth, Sr.  Opened
#
#                                        Primary_Party Violation_Date  \
# 0                                    SANDERS, JUNE E     2011-01-04
# 1                                COOK, CHRISTOPHER H     2018-08-02
# 2                               ALLEN, ELIZABETH SUE     2012-05-16
# 3  ARC COMMUNITIES 6 LLC              ,          ...     2010-05-17
# 4                                 HARRIS MARCELOUS M     2010-03-23
#
#    Compliance Received_By   PARCEL_CLEAN   LATITUDE  LONGITUDE  Prop_Use_Code  \
# 0  2011-01-04    By Phone  05977-217-000  29.735988 -82.384887          200.0
# 1  2018-08-02      311GNV  05977-276-000  29.732794 -82.386024          200.0
# 2  2012-05-16    By Phone  05979-056-000  29.733962 -82.382726          100.0
# 3  2010-05-17    By Phone  05983-000-000  29.735166 -82.374964         2800.0
# 4  2010-03-23  CE Officer  06006-040-030  29.726796 -82.399143          100.0
#
#     Prop_Use_Desc TRS_WATSON SECTION_1 TOWNSHIP_1 RANGE_1 TD RD
# 0     MOBILE HOME  09S19E002       002         09      19  S  E
# 1     MOBILE HOME  09S19E002       002         09      19  S  E
# 2   SINGLE FAMILY  09S19E002       002         09      19  S  E
# 3  PKG LOT (COMM)  09S19E002       002         09      19  S  E
# 4   SINGLE FAMILY  09S19E010       010         09      19  S  E

# %% [markdown]
# ## Number of each Blight Violation

# %%
blight_violations['Violation'].value_counts()
# Out:
# Abandoned Vehicles And/or Blight Inducing Materials    3597
# Blight-inducing Materials                              2663
# Name: Violation, dtype: int64

# %%
total_blight = blight_violations['Number'].count()
print(total_blight)
# Out:
# 6260

# %% [markdown]
# ### Percent of Total Violations

# %%
total_violations = violations.shape[0]
blight_violations['Number'].count() / total_violations
# Out:
# 0.2246707102609195

# %% [markdown]
# ## Blight Complaint Sources

# %% [markdown]
# #### Number from each Complaint Source

# %%
#whats the difference between proactive and CE officer?
blight_complaint_source = blight_violations.groupby('Received_By').count()["Number"]
print(blight_complaint_source)
# Out:
# Received_By
# 311GNV         104
# Admin           13
# By Email       103
# By Mail         15
# By Phone       543
# CE Officer    4596
# MANAGER          8
# Proactive      774
# SUPERVISOR      24
# Voice Mail      15
# Walk In         45
# Name: Number, dtype: int64

# %% [markdown]
# #### Percent of Total blight violations

# %%
blight_complaint_source / total_blight *100
# Out:
# Received_By
# 311GNV         1.661342
# Admin          0.207668
# By Email       1.645367
# By Mail        0.239617
# By Phone       8.674121
# CE Officer    73.418530
# MANAGER        0.127796
# Proactive     12.364217
# SUPERVISOR     0.383387
# Voice Mail     0.239617
# Walk In        0.718850
# Name: Number, dtype: float64

# %% [markdown]
# ## Complaint Sources from All Majorhousing Violations

# %%
complaint_source = violations.groupby('Received_By').count()["Number"]
print(complaint_source)
# Out:
# Received_By
# 311GNV          492
# Admin            68
# By Email        680
# By Fax            1
# By Mail          60
# By Phone       6317
# CE Officer    16226
# MANAGER          54
# Proactive      3135
# SUPERVISOR      122
# Voice Mail      157
# Walk In         371
# Name: Number, dtype: int64

# %%
complaint_source / total_violations *100
# Out:
# Received_By
# 311GNV         1.765783
# Admin          0.244051
# By Email       2.440513
# By Fax         0.003589
# By Mail        0.215339
# By Phone      22.671643
# CE Officer    58.234935
# MANAGER        0.193805
# Proactive     11.251480
# SUPERVISOR     0.437857
# Voice Mail     0.563471
# Walk In        1.331515
# Name: Number, dtype: float64

# %% [markdown]
# #### 12.3% of blight violations are proactively found, marginally higher then the 11.2% out of all violations.
# #### 73.4% of blight violations are found by CE Officers, which is significantly higher then the 58.2% out of all Violations

# %%
sns.distplot(x="time", y="tip", data = blight_violations.groupby(blight_violations['Violation_Date'].map(lambda x: x.year)).count()['Number'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-184-b27f1dbb1fdc> in <module>()
# ----> 1 sns.distplot(x="time", y="tip", data = blight_violations.groupby(blight_violations['Violation_Date'].map(lambda x: x.year)).count()['Number'])
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %% [markdown]
# ## Violations by Property Type

# %%
blight_violations.groupby('Prop_Use_Desc').count()['Number']
# Out:
# Prop_Use_Desc
# CHURCHES                       13
# CLB/LDG/UN HALL                 6
# COMMON AREA                     5
# CONDOMINIUM                    20
# FINANCIAL                       1
# MFR <10 UNITS                 399
# MISC. RESIDENCE                61
# MOBILE HOME                    26
# MOTEL                           3
# MULTIFAMILY                    48
# MUNICIPAL                       8
# MUNICIPAL VACANT/XFEATURE       5
# OFFICE 1 STORY                  7
# ORPHNG/NON-PROF                 1
# PKG LOT (COMM)                 11
# PROF OFFICES                    3
# PRV SCHL/COLL                   3
# REST DRIVE-IN                   1
# SERVICE SHOPS                   4
# SH CTR NBHD                     1
# SINGLE FAMILY                5317
# STATE(TIITF) VACANT/XF          2
# STORE/OFF/RES                   9
# STORES                         11
# TMBR SI 80-89                   1
# UTILITY                         1
# VACANT                        205
# VACANT COMM                    40
# VACANT INDUSTRIAL               1
# WAREH/DIST TERM                 2
# Name: Number, dtype: int64

# %%
# Out:
#             Number                                          Violation  \
# 1      CE-10-03462                          Blight-inducing Materials
# 16     CE-18-01217  Abandoned Vehicles And/or Blight Inducing Mate...
# 43     CE-10-03463                          Blight-inducing Materials
# 56     CE-10-01790                          Blight-inducing Materials
# 66     CE-10-00340                          Blight-inducing Materials
# 69     CE-15-00133  Abandoned Vehicles And/or Blight Inducing Mate...
# 78     CE-05-06730  Abandoned Vehicles And/or Blight Inducing Mate...
# 79     CE-14-00538  Abandoned Vehicles And/or Blight Inducing Mate...
# 86     CE-15-02803  Abandoned Vehicles And/or Blight Inducing Mate...
# 93     CE-18-02126  Abandoned Vehicles And/or Blight Inducing Mate...
# 100    CE-99-00357  Abandoned Vehicles And/or Blight Inducing Mate...
# 101    CE-99-01409  Abandoned Vehicles And/or Blight Inducing Mate...
# 102    CE-99-01411  Abandoned Vehicles And/or Blight Inducing Mate...
# 103    CE-05-04513  Abandoned Vehicles And/or Blight Inducing Mate...
# 104    CE-05-06446  Abandoned Vehicles And/or Blight Inducing Mate...
# 106    CE-05-03234  Abandoned Vehicles And/or Blight Inducing Mate...
# 107    CE-05-04523  Abandoned Vehicles And/or Blight Inducing Mate...
# 108    CE-18-01277  Abandoned Vehicles And/or Blight Inducing Mate...
# 117    CE-18-02726  Abandoned Vehicles And/or Blight Inducing Mate...
# 132    CE-09-01839                          Blight-inducing Materials
# 153    CE-16-00255  Abandoned Vehicles And/or Blight Inducing Mate...
# 167    CE-10-02462                          Blight-inducing Materials
# 179    CE-11-02911                          Blight-inducing Materials
# 352    CE-06-00478                          Blight-inducing Materials
# 355    CE-02-05246                          Blight-inducing Materials
# 358    CE-11-01205                          Blight-inducing Materials
# 360    CE-14-01210  Abandoned Vehicles And/or Blight Inducing Mate...
# 361    CE-18-02958  Abandoned Vehicles And/or Blight Inducing Mate...
# 362    CE-06-05443                          Blight-inducing Materials
# 363    CE-07-05957                          Blight-inducing Materials
# ...            ...                                                ...
# 26879  CE-04-08508                          Blight-inducing Materials
# 26880  CE-04-08508                          Blight-inducing Materials
# 26881  CE-05-05545                          Blight-inducing Materials
# 26901  CE-04-05986  Abandoned Vehicles And/or Blight Inducing Mate...
# 26902  CE-06-06333  Abandoned Vehicles And/or Blight Inducing Mate...
# 26903  CE-06-08204                          Blight-inducing Materials
# 26904  CE-08-08125                          Blight-inducing Materials
# 26906  CE-14-01490  Abandoned Vehicles And/or Blight Inducing Mate...
# 26907  CE-15-00946  Abandoned Vehicles And/or Blight Inducing Mate...
# 26908  CE-18-01822  Abandoned Vehicles And/or Blight Inducing Mate...
# 26909  CE-18-02472  Abandoned Vehicles And/or Blight Inducing Mate...
# 26911  CE-05-03473  Abandoned Vehicles And/or Blight Inducing Mate...
# 26912  CE-06-06352  Abandoned Vehicles And/or Blight Inducing Mate...
# 26917  CE-16-00316  Abandoned Vehicles And/or Blight Inducing Mate...
# 26922  CE-05-02612  Abandoned Vehicles And/or Blight Inducing Mate...
# 26925  CE-03-03980  Abandoned Vehicles And/or Blight Inducing Mate...
# 26927  CE-03-05882                          Blight-inducing Materials
# 26942  CE-03-07379  Abandoned Vehicles And/or Blight Inducing Mate...
# 26944  CE-04-01195                          Blight-inducing Materials
# 26950  CE-02-03444  Abandoned Vehicles And/or Blight Inducing Mate...
# 26951  CE-03-06798  Abandoned Vehicles And/or Blight Inducing Mate...
# 26952  CE-00-03628                          Blight-inducing Materials
# 26953  CE-02-04784  Abandoned Vehicles And/or Blight Inducing Mate...
# 26962  CE-03-08126                          Blight-inducing Materials
# 26963  CE-16-02656  Abandoned Vehicles And/or Blight Inducing Mate...
# 26970  CE-01-05693  Abandoned Vehicles And/or Blight Inducing Mate...
# 27018  CE-01-04027                          Blight-inducing Materials
# 27019  CE-03-09300                          Blight-inducing Materials
# 27861  CE-07-10411  Abandoned Vehicles And/or Blight Inducing Mate...
# 27862  CE-16-00529  Abandoned Vehicles And/or Blight Inducing Mate...
#
#                   Inspector   Status  \
# 1      Walter L. Booth, Sr.   Opened
# 16              Todd Martin   Opened
# 43     Walter L. Booth, Sr.   Opened
# 56     Walter L. Booth, Sr.   Opened
# 66     Walter L. Booth, Sr.   Opened
# 69     Walter L. Booth, Sr.   Opened
# 78          Default Officer   Closed
# 79           Lorie Podolsky   Opened
# 86     Walter L. Booth, Sr.   Opened
# 93          Samantha Norris   Opened
# 100         Default Officer  Dropped
# 101         Default Officer   Abated
# 102         Default Officer   Abated
# 103         Default Officer   Closed
# 104         Default Officer   Closed
# 106         Default Officer   Closed
# 107         Default Officer   Closed
# 108             Curt Eichel   Opened
# 117         Samantha Norris   Opened
# 132         Default Officer   Closed
# 153    Walter L. Booth, Sr.   Opened
# 167    Walter L. Booth, Sr.   Opened
# 179    Walter L. Booth, Sr.   Opened
# 352         Default Officer   Closed
# 355         Default Officer   Closed
# 358    Walter L. Booth, Sr.   Opened
# 360          Lorie Podolsky   Opened
# 361              Brey Moore   Opened
# 362         Default Officer   Closed
# 363         Default Officer   Closed
# ...                     ...      ...
# 26879       Default Officer   Closed
# 26880       Default Officer   Closed
# 26881       Default Officer   Closed
# 26901       Default Officer   Closed
# 26902       Default Officer   Closed
# 26903       Default Officer   Closed
# 26904       Default Officer   Closed
# 26906       Jeffrey S. Look   Opened
# 26907          Steven Baker   Opened
# 26908          Steven Baker   Opened
# 26909          E. Di Muccio   Opened
# 26911       Default Officer   Closed
# 26912       Default Officer   Closed
# 26917          Steven Baker   Opened
# 26922       Default Officer   Closed
# 26925       Default Officer   Closed
# 26927       Default Officer   Closed
# 26942       Default Officer   Closed
# 26944       Default Officer   Closed
# 26950       Default Officer   Closed
100.0   SINGLE FAMILY  09S19E013       013         09      19
# 362            100.0   SINGLE FAMILY  09S19E013       013         09      19
# 363            100.0   SINGLE FAMILY  09S19E013       013         09      19
# ...              ...             ...        ...       ...        ...     ...
# 26879            NaN             NaN        NaN       NaN        NaN     NaN
# 26880            NaN             NaN        NaN       NaN        NaN     NaN
# 26881            NaN             NaN        NaN       NaN        NaN     NaN
# 26901            NaN             NaN        NaN       NaN        NaN     NaN
# 26902            NaN             NaN        NaN       NaN        NaN     NaN
# 26903            NaN             NaN        NaN       NaN        NaN     NaN
# 26904            NaN             NaN        NaN       NaN        NaN     NaN
# 26906            NaN             NaN        NaN       NaN        NaN     NaN
# 26907            NaN             NaN        NaN       NaN        NaN     NaN
# 26908            NaN             NaN        NaN       NaN        NaN     NaN
# 26909            NaN             NaN        NaN       NaN        NaN     NaN
# 26911            NaN             NaN        NaN       NaN        NaN     NaN
# 26912            NaN             NaN        NaN       NaN        NaN     NaN
# 26917            NaN             NaN        NaN       NaN        NaN     NaN
# 26922            NaN             NaN        NaN       NaN        NaN     NaN
# 26925            NaN             NaN        NaN       NaN        NaN     NaN
# 26927            NaN             NaN        NaN       NaN        NaN     NaN
# 26942            NaN             NaN        NaN       NaN        NaN     NaN
# 26944            NaN             NaN        NaN       NaN        NaN     NaN
# 26950            NaN             NaN        NaN       NaN        NaN     NaN
# 26951            NaN             NaN        NaN       NaN        NaN     NaN
# 26952            NaN             NaN        NaN       NaN        NaN     NaN
# 26953            NaN             NaN        NaN       NaN        NaN     NaN
# 26962            NaN             NaN        NaN       NaN        NaN     NaN
# 26963            NaN             NaN        NaN       NaN        NaN     NaN
# 26970            NaN             NaN        NaN       NaN        NaN     NaN
# 27018            NaN             NaN        NaN       NaN        NaN     NaN
# 27019            NaN             NaN        NaN       NaN        NaN     NaN
# 27861            NaN             NaN        NaN       NaN        NaN     NaN
# 27862            NaN             NaN        NaN       NaN        NaN     NaN
#
#         TD   RD
# 1        S    E
# 16       S    E
# 43       S    E
# 56       S    E
# 66       S    E
# 69       S    E
# 78       S    E
# 79       S    E
# 86       S    E
# 93       S    E
# 100      S    E
# 101      S    E
# 102      S    E
# 103      S    E
# 104      S    E
# 106      S    E
# 107      S    E
# 108      S    E
# 117      S    E
# 132      S    E
# 153      S    E
# 167      S    E
# 179      S    E
# 352      S    E
# 355      S    E
# 358      S    E
# 360      S    E
# 361      S    E
# 362      S    E
# 363      S    E
# ...    ...  ...
# 26879  NaN  NaN
# 26880  NaN  NaN
# 26881  NaN  NaN
# 26901  NaN  NaN
# 26902  NaN  NaN
# 26903  NaN  NaN
# 26904  NaN  NaN
# 26906  NaN  NaN
# 26907  NaN  NaN
# 26908  NaN  NaN
# 26909  NaN  NaN
# 26911  NaN  NaN
# 26912  NaN  NaN
# 26917  NaN  NaN
# 26922  NaN  NaN
# 26925  NaN  NaN
# 26927  NaN  NaN
# 26942  NaN  NaN
# 26944  NaN  NaN
# 26950  NaN  NaN
# 26951  NaN  NaN
# 26952  NaN  NaN
# 26953  NaN  NaN
# 26962  NaN  NaN
# 26963  NaN  NaN
# 26970  NaN  NaN
# 27018  NaN  NaN
# 27019  NaN  NaN
# 27861  NaN  NaN
# 27862  NaN  NaN
#
# [6260 rows x 19 columns]
