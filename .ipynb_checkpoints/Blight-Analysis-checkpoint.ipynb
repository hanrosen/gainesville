# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
mjr_violations_orig = pd.read_csv('data/mjrhouse_violations.csv')

# %%
violations = mjr_violations_orig
violations.shape
# Out:
# (27863, 34)

# %%
violations.head()
# Out:
#         Number                     Violation  \
# 0  CE-15-02088        Overgrown Yard / Weeds
# 1  CE-10-03462     Blight-inducing Materials
# 2  CE-09-06929  Dead Tree or Hazardous Trees
# 3  CE-09-06929        Overgrown Yard / Weeds
# 4  CE-15-02201        Overgrown Yard / Weeds
#
#                             Case_Type             Inspector  Status  \
# 0  MJRHOUSE - Major Housing Violation  Walter L. Booth, Sr.  Opened
# 1  MJRHOUSE - Major Housing Violation  Walter L. Booth, Sr.  Opened
# 2  MJRHOUSE - Major Housing Violation  Walter L. Booth, Sr.  Opened
# 3  MJRHOUSE - Major Housing Violation  Walter L. Booth, Sr.  Opened
# 4  MJRHOUSE - Major Housing Violation  Walter L. Booth, Sr.  Opened
#
#                              Primary_Party Violation_Date Resolve  Compliance  \
# 0                          ALAN  SCHNEIDER     2015-09-11     NaN  2015-12-18
# 1                          SANDERS, JUNE E     2010-09-27     NaN  2011-01-04
# 2                                ADD PARTY     2009-10-27     NaN  2010-03-22
# 3                                ADD PARTY     2009-10-27     NaN  2010-03-22
# 4  TURKEY CREEK FOREST OWNERS, ASSOCIATION     2015-09-18     NaN  2015-10-08
#
#   Compliance_Requested    ...    Prop_Use_Code Prop_Use_Desc TRS_WATSON  \
# 0           2015-10-11    ...            200.0   MOBILE HOME  09S19E002
# 1           2010-10-08    ...            200.0   MOBILE HOME  09S19E002
# 2           2010-03-08    ...            200.0   MOBILE HOME  09S19E002
# 3           2010-03-08    ...            200.0   MOBILE HOME  09S19E002
# 4           2015-10-04    ...            200.0   MOBILE HOME  09S19E002
#
#   SECTION_1 TOWNSHIP_1 RANGE_1 TD  RD   COUNTY  DESCRIPT
# 0       002         09      19  S   E  ALACHUA  09S19E02
# 1       002         09      19  S   E  ALACHUA  09S19E02
# 2       002         09      19  S   E  ALACHUA  09S19E02
# 3       002         09      19  S   E  ALACHUA  09S19E02
# 4       002         09      19  S   E  ALACHUA  09S19E02
#
# [5 rows x 34 columns]

# %%
violations.drop(['Resolve','Compliance_Requested','Case_Type','CEB_Compliance_Requested','Tag_', 'VIN_',
       'Make', 'Color','Vehicle_Description', 'Address', 'Quantity','PARCEL_1', 'MAPSHEET','COUNTY', 'DESCRIPT'], axis=1, inplace = True)
violations.columns
# Out:
# Index(['Number', 'Violation', 'Inspector', 'Status', 'Primary_Party',
#        'Violation_Date', 'Compliance', 'Received_By', 'PARCEL_CLEAN',
#        'LATITUDE', 'LONGITUDE', 'Prop_Use_Code', 'Prop_Use_Desc', 'TRS_WATSON',
#        'SECTION_1', 'TOWNSHIP_1', 'RANGE_1', 'TD', 'RD'],
#       dtype='object')

# %%
#change to datetime format
violations["Violation_Date"] = pd.to_datetime(violations["Violation_Date"])
violations["Violation_Date"] = pd.to_datetime(violations['Compliance'])

# %% [markdown]
# # Blight Violations

# %%
blight_violations = violations[violations['Violation'].isin(['Blight-inducing Materials','Abandoned Vehicles And/or Blight Inducing Materials'])].reset_index(drop=True)
blight_violations.head()
# Out:
#         Number                                          Violation  \
# 0  CE-10-03462                          Blight-inducing Materials
# 1  CE-18-01217  Abandoned Vehicles And/or Blight Inducing Mate...
# 2  CE-10-03463                          Blight-inducing Materials
# 3  CE-10-01790                          Blight-inducing Materials
# 4  CE-10-00340                          Blight-inducing Materials
#
#               Inspector  Status  \
# 0  Walter L. Booth, Sr.  Opened
# 1           Todd Martin  Opened
# 2  Walter L. Booth, Sr.  Opened
# 3  Walter L. Booth, Sr.  Opened
# 4  Walter L. Booth, Sr.  Opened
#
#                                        Primary_Party Violation_Date  \
# 0                                    SANDERS, JUNE E     2011-01-04
# 1                                COOK, CHRISTOPHER H     2018-08-02
# 2                               ALLEN, ELIZABETH SUE     2012-05-16
# 3  ARC COMMUNITIES 6 LLC              ,          ...     2010-05-17
# 4                                 HARRIS MARCELOUS M     2010-03-23
#
#    Compliance Received_By   PARCEL_CLEAN   LATITUDE  LONGITUDE  Prop_Use_Code  \
# 0  2011-01-04    By Phone  05977-217-000  29.735988 -82.384887          200.0
# 1  2018-08-02      311GNV  05977-276-000  29.732794 -82.386024          200.0
# 2  2012-05-16    By Phone  05979-056-000  29.733962 -82.382726          100.0
# 3  2010-05-17    By Phone  05983-000-000  29.735166 -82.374964         2800.0
# 4  2010-03-23  CE Officer  06006-040-030  29.726796 -82.399143          100.0
#
#     Prop_Use_Desc TRS_WATSON SECTION_1 TOWNSHIP_1 RANGE_1 TD RD
# 0     MOBILE HOME  09S19E002       002         09      19  S  E
# 1     MOBILE HOME  09S19E002       002         09      19  S  E
# 2   SINGLE FAMILY  09S19E002       002         09      19  S  E
# 3  PKG LOT (COMM)  09S19E002       002         09      19  S  E
# 4   SINGLE FAMILY  09S19E010       010         09      19  S  E

# %%
# violations['blight'] = violations['Violation'].isin(['Blight-inducing Materials','Abandoned Vehicles And/or Blight Inducing Materials']).astype(int)

# violations.head()

# %% [markdown]
# ## Number of each Blight Violation

# %%
blight_violations['Violation'].value_counts()
# Out:
# Abandoned Vehicles And/or Blight Inducing Materials    3597
# Blight-inducing Materials                              2663
# Name: Violation, dtype: int64

# %%
total_blight = blight_violations['Number'].count()
print(total_blight)
# Out:
# 6260

# %% [markdown]
# ### Percent of Total Violations

# %%
total_violations = violations.shape[0]
blight_violations['Number'].count() / total_violations
# Out:
# 0.2246707102609195

# %% [markdown]
# ## Blight Complaint Sources

# %% [markdown]
# #### Number from each Complaint Source

# %%
#whats the difference between proactive and CE officer?
blight_complaint_source = blight_violations.groupby('Received_By').count()["Number"]
print(blight_complaint_source)
# Out:
# Received_By
# 311GNV         104
# Admin           13
# By Email       103
# By Mail         15
# By Phone       543
# CE Officer    4596
# MANAGER          8
# Proactive      774
# SUPERVISOR      24
# Voice Mail      15
# Walk In         45
# Name: Number, dtype: int64

# %% [markdown]
# #### Percent of Total blight violations

# %%
blight_complaint_source / total_blight *100
# Out:
# Received_By
# 311GNV         1.661342
# Admin          0.207668
# By Email       1.645367
# By Mail        0.239617
# By Phone       8.674121
# CE Officer    73.418530
# MANAGER        0.127796
# Proactive     12.364217
# SUPERVISOR     0.383387
# Voice Mail     0.239617
# Walk In        0.718850
# Name: Number, dtype: float64

# %% [markdown]
# ## Complaint Sources from All Majorhousing Violations

# %%
complaint_source = violations.groupby('Received_By').count()["Number"]
print(complaint_source)
# Out:
# Received_By
# 311GNV          492
# Admin            68
# By Email        680
# By Fax            1
# By Mail          60
# By Phone       6317
# CE Officer    16226
# MANAGER          54
# Proactive      3135
# SUPERVISOR      122
# Voice Mail      157
# Walk In         371
# Name: Number, dtype: int64

# %%
complaint_source / total_violations *100
# Out:
# Received_By
# 311GNV         1.765783
# Admin          0.244051
# By Email       2.440513
# By Fax         0.003589
# By Mail        0.215339
# By Phone      22.671643
# CE Officer    58.234935
# MANAGER        0.193805
# Proactive     11.251480
# SUPERVISOR     0.437857
# Voice Mail     0.563471
# Walk In        1.331515
# Name: Number, dtype: float64

# %% [markdown]
# #### 12.3% of blight violations are proactively found, marginally higher then the 11.2% out of all violations.
# #### 73.4% of blight violations are found by CE Officers, which is significantly higher then the 58.2% out of all Violations

# %% [markdown]
# # Blight Violation by Month

# %%
blight_violations["month"] = blight_violations['Violation_Date'].map(lambda x: x.month)
blight_violations["year"] = blight_violations['Violation_Date'].map(lambda x: x.year)

# %%
blight_violations_new = blight_violations[blight_violations['year'] > 2009]

fig, ax = plt.subplots(figsize=(15,7))

blight_violations_new.groupby(['month','year']).count()['Number'].unstack().plot(ax=ax)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Violations by Year

# %%
blight_by_year = blight_violations.groupby(blight_violations['Violation_Date'].map(lambda x: x.year)).count()['Number'].to_frame()
vio_by_year = violations.groupby(violations['Violation_Date'].map(lambda x: x.year)).count()['Number'].to_frame()

percent_blight_per_year = blight_by_year['Number'] / vio_by_year['Number']

# %% [markdown]
# ### Total Housing Violations by Year

# %%
plt.plot(vio_by_year)

# %% [markdown]
# ### Blight Violations by Year

# %%
plt.plot(blight_by_year)

# %% [markdown]
# ### Percent of blight violations per year

# %%
plt.plot(percent_blight_per_year)

# %%
### blight violations

# %% [markdown]
# # Violations by Property Type

# %%
blight_prop_type = blight_violations.groupby('Prop_Use_Desc').count().sort_values('Number',ascending=False)['Number']
(blight_prop_type / total_blight * 100)
# Out:
# Prop_Use_Desc
# SINGLE FAMILY                84.936102
# MFR <10 UNITS                 6.373802
# VACANT                        3.274760
# MISC. RESIDENCE               0.974441
# MULTIFAMILY                   0.766773
# VACANT COMM                   0.638978
# MOBILE HOME                   0.415335
# CONDOMINIUM                   0.319489
# CHURCHES                      0.207668
# STORES                        0.175719
# PKG LOT (COMM)                0.175719
# STORE/OFF/RES                 0.143770
# MUNICIPAL                     0.127796
# OFFICE 1 STORY                0.111821
# CLB/LDG/UN HALL               0.095847
# COMMON AREA                   0.079872
# MUNICIPAL VACANT/XFEATURE     0.079872
# SERVICE SHOPS                 0.063898
# PROF OFFICES                  0.047923
# PRV SCHL/COLL                 0.047923
# MOTEL                         0.047923
# STATE(TIITF) VACANT/XF        0.031949
# WAREH/DIST TERM               0.031949
# SH CTR NBHD                   0.015974
# REST DRIVE-IN                 0.015974
# ORPHNG/NON-PROF               0.015974
# TMBR SI 80-89                 0.015974
# UTILITY                       0.015974
# FINANCIAL                     0.015974
# VACANT INDUSTRIAL             0.015974
# Name: Number, dtype: float64

# %%
# Number of NA's in blight property types
total_blight - blight_prop_type.sum()
# Out:
# 45

# %% [markdown]
# ### A significant majority (84.9%) of blight violations are from single family homes, followed by Mult Units of < 10 (6.37%) and Vacant homes (3.27%)

# %% [markdown]
# # Blight by Primary Party

# %%
primary_party = blight_violations.groupby("Primary_Party").count().sort_values('Number',ascending=False)['Number']
primary_party = primary_party.to_frame()
primary_party_frame = primary_party[3:14]
# primary_party.index

# %%
plot = sns.barplot(x=primary_party_frame.index, y="Number", data=primary_party_frame,
            label="Total", color="b")
plot.set_xticklabels(plot.get_xticklabels(), rotation=45)
# Out:
# [Text(0,0,'DOWST JONI'),
#  Text(0,0,'LONG TODD'),
#  Text(0,0,'JIM GARRETT'),
#  Text(0,0,'SHEPPARD ERNEST LEE'),
#  Text(0,0,'ANONYMOUS'),
#  Text(0,0,'MOSS CATHERINE'),
#  Text(0,0,'LOWE, ISSIE ANN TRUSTEE'),
#  Text(0,0,'WONG & WU H/W, '),
#  Text(0,0,'CULVER DEBORAH'),
#  Text(0,0,'RIGGINS SUZETTA'),
#  Text(0,0,'SMITH CHESTER F')]

# %%
primary_party = primary_party[3:]

primary_party.shape
# Out:
# (4313, 1)

# %%
primary_party[primary_party["Number"] > 1].count()
# Out:
# Number    1040
# dtype: int64

# %%
print("Number of repeat offenders: ")
1037/4310
# Out:
# Number of repeat offenders:
# 0.2406032482598608

# %%
parcels = blight_violations.groupby("PARCEL_CLEAN").count().sort_values('Number',ascending=False)['Number']
parcels.head()
# blight_violations
# Out:
# PARCEL_CLEAN
# 07918-025-031    14
# 06104-010-008    12
# 06066-028-000    11
# 12515-000-000    10
# 06398-021-000    10
# Name: Number, dtype: int64

# %% [markdown]
# # Top 10 Violations Over Time

# %%
violation_desc = violations.groupby('Violation').count().sort_values('Number', ascending = False)['Number'].to_frame()
violation_desc.head()
# Out:
#                                                     Number
# Violation
# Overgrown Yard / Weeds                                3970
# Abandoned Vehicles And/or Blight Inducing Mater...    3597
# Blight-inducing Materials                             2663
# Hazardous Condition - Residential                     1098
# Dead Tree or Hazardous Trees                           988

# %%
violation_desc_10 = violation_desc[violation_desc["Number"] != 1][:10].to_dict()

vio_10 = [] 
for x in violation_desc_10['Number'].keys():  
    vio_10.append(x)

vio_10
# Out:
# ['Overgrown Yard / Weeds',
#  'Abandoned Vehicles And/or Blight Inducing Materials',
#  'Blight-inducing Materials',
#  'Hazardous Condition - Residential',
#  'Dead Tree or Hazardous Trees',
#  'Interior Holes Sealed',
#  'Smoke Detectors',
#  'Conversion Only (violation)',
#  'Trash & Garbage',
#  'Insects, Rodents and Vermin; Natural Drainage']

# %%
violations["month"] = violations['Violation_Date'].map(lambda x: x.month)
violations["year"] = violations['Violation_Date'].map(lambda x: x.year)


new_violations = violations[violations['Violation'].isin(vio_10) == True]
new_violations.head()
# Out:
#         Number                     Violation             Inspector  Status  \
# 0  CE-15-02088        Overgrown Yard / Weeds  Walter L. Booth, Sr.  Opened
# 1  CE-10-03462     Blight-inducing Materials  Walter L. Booth, Sr.  Opened
# 2  CE-09-06929  Dead Tree or Hazardous Trees  Walter L. Booth, Sr.  Opened
# 3  CE-09-06929        Overgrown Yard / Weeds  Walter L. Booth, Sr.  Opened
# 4  CE-15-02201        Overgrown Yard / Weeds  Walter L. Booth, Sr.  Opened
#
#                              Primary_Party Violation_Date  Compliance  \
# 0                          ALAN  SCHNEIDER     2015-12-18  2015-12-18
# 1                          SANDERS, JUNE E     2011-01-04  2011-01-04
# 2                                ADD PARTY     2010-03-22  2010-03-22
# 3                                ADD PARTY     2010-03-22  2010-03-22
# 4  TURKEY CREEK FOREST OWNERS, ASSOCIATION     2015-10-08  2015-10-08
#
#   Received_By   PARCEL_CLEAN   LATITUDE   ...    Prop_Use_Code  Prop_Use_Desc  \
# 0      311GNV  05977-215-000  29.735921   ...            200.0    MOBILE HOME
# 1    By Phone  05977-217-000  29.735988   ...            200.0    MOBILE HOME
# 2  CE Officer  05977-217-000  29.735988   ...            200.0    MOBILE HOME
# 3  CE Officer  05977-217-000  29.735988   ...            200.0    MOBILE HOME
# 4      311GNV  05977-217-000  29.735988   ...            200.0    MOBILE HOME
#
#   TRS_WATSON SECTION_1 TOWNSHIP_1 RANGE_1 TD RD month    year
# 0  09S19E002       002         09      19  S  E  12.0  2015.0
# 1  09S19E002       002         09      19  S  E   1.0  2011.0
# 2  09S19E002       002         09      19  S  E   3.0  2010.0
# 3  09S19E002       002         09      19  S  E   3.0  2010.0
# 4  09S19E002       002         09      19  S  E  10.0  2015.0
#
# [5 rows x 21 columns]

# %%
fig, ax = plt.subplots(figsize=(15,7))

new_violations.groupby(['year','Violation']).count()['Number'].unstack().plot(ax=ax)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
